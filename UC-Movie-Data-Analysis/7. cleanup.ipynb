-- %%
USE CATALOG movielens_dev;

-- %%
SHOW SCHEMAS

-- %%
DROP SCHEMA IF EXISTS movielens_gold CASCADE;
DROP SCHEMA IF EXISTS movielens_silver CASCADE;
DROP SCHEMA IF EXISTS movielens_bronze CASCADE;
DROP SCHEMA IF EXISTS movielens_landing CASCADE;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
DROP EXTERNAL LOCATION IF EXISTS movielens_gold FORCE;
DROP EXTERNAL LOCATION IF EXISTS movielens_silver FORCE;
DROP EXTERNAL LOCATION IF EXISTS movielens_bronze FORCE;
DROP EXTERNAL LOCATION IF EXISTS movielens_landing FORCE;
