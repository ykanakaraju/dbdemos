-- %%
USE CATALOG movielens_dev

-- %%
SHOW SCHEMAS

-- %%
SHOW TABLES IN movielens_gold;

-- %%
DROP TABLE IF EXISTS movielens_landing.movies;
DROP TABLE IF EXISTS movielens_landing.ratings;

DROP TABLE IF EXISTS movielens_bronze.movies;
DROP TABLE IF EXISTS movielens_bronze.ratings;

DROP TABLE IF EXISTS movielens_silver.movie_ratings;
DROP TABLE IF EXISTS movielens_silver.movie_ratings_genres;

DROP TABLE IF EXISTS movielens_gold.moviesbygenre;
DROP TABLE IF EXISTS movielens_gold.top20movies;

-- %%
SHOW SCHEMAS

-- %%
DROP SCHEMA IF EXISTS movielens_gold CASCADE;
DROP SCHEMA IF EXISTS movielens_silver CASCADE;
DROP SCHEMA IF EXISTS movielens_bronze CASCADE;
DROP SCHEMA IF EXISTS movielens_landing CASCADE;

-- %%
DROP CATALOG movielens_dev CASCADE;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
DROP EXTERNAL LOCATION IF EXISTS movielens_landing;
DROP EXTERNAL LOCATION IF EXISTS movielens_bronze;
DROP EXTERNAL LOCATION IF EXISTS movielens_silver;
DROP EXTERNAL LOCATION IF EXISTS movielens_gold;
