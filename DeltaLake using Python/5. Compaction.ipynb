# %% [markdown]
# ###Compaction of Delta Tables###

# %% [markdown]
# **Compaction is a process of merging too many small files into fewer large files.**
#
# * Click [here](https://docs.delta.io/latest/best-practices.html#-delta-compact-files) for the documentation related to compaction of Delta Files.

# %%
# %run "../Includes/utils"

# %%
# %sql
USE students_db;

# %%
# %sql
SELECT * FROM students

# %%
from delta.tables import DeltaTable
students_delta = DeltaTable.forName(spark, "students_db.students")

# %%
students_delta.toDF().display()

# %%
students_delta.detail().display()

# %% [markdown]
# **Compaction of delta table**

# %%
help(students_delta.optimize)

# %%
students_delta.optimize().executeCompaction()
#students_delta.optimize().executeZOrderBy(["student_id"])

# %%
students_delta.history().display()

# %%
students_delta.detail().display()

# %%
students_delta.restoreToVersion(3)

# %%
students_delta.history().display()

# %%
students_delta.detail().display()

# %%
students_delta.optimize().executeZOrderBy(["student_id"])

# %%
students_delta.history().display()

# %% [markdown]
# **Equivalent command in SQL**

# %%
# %sql
-- OPTIMIZE students_db.students
-- OPTIMIZE students_db.students ZORDER BY (stuudent_id)

# %%
#students_delta.restoreToVersion(5)
