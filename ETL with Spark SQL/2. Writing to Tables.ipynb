-- %%
%python
dataset_bookstore = "dbfs:/FileStore/data/bookstore"
spark.conf.set(f"dataset.bookstore", dataset_bookstore)

-- %% [markdown]
-- #### Creating Tables

-- %%
CREATE TABLE orders AS
SELECT * FROM parquet.`${dataset.bookstore}/orders`

-- %% [markdown]
-- #### Overwriting Tables

-- %%
-- Create a new table or overwrite an existing table

-- %%
-- overwrite data of an existing table

-- %% [markdown]
-- #### Appending Data

-- %%
-- append data to an existing table

-- %% [markdown]
-- #### Merging Data

-- %%
CREATE OR REPLACE TEMP VIEW customers_updates AS 
SELECT * FROM json.`${dataset.bookstore}/customers-json-new`;

-- %%
-- merge customers_updates into customers table

-- %% [markdown]
-- **An other example**

-- %%
CREATE OR REPLACE TEMP VIEW books_updates
   (book_id STRING, title STRING, author STRING, category STRING, price DOUBLE)
USING CSV
OPTIONS (
  path = "${dataset.bookstore}/books-csv-new",
  header = "true",
  delimiter = ";"
);

-- %%
SELECT * FROM books_updates

-- %%
SELECT * FROM books

-- %%
-- merge books_updates into books table
