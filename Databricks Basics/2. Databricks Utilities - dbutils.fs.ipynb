# %%
file_path = "/Volumes/workspace/default/data"

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
files = dbutils.fs.ls(file_path)
for file in files:
    if (file.name.endswith(".json")):
        print(file.path)
# Out:
# dbfs:/Volumes/workspace/default/data/users-nested.json
# dbfs:/Volumes/workspace/default/data/users.json
# dbfs:/Volumes/workspace/default/data/users_malformed.json
# dbfs:/Volumes/workspace/default/data/users_multiline.json

# %%
display(dbutils.fs.ls(file_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.mkdirs(file_path + "/demo1")
# Out:
# True

# %%
dbutils.fs.mkdirs(file_path + "/demo2")
# Out:
# True

# %%
for file in dbutils.fs.ls(file_path):
    if (file.name.endswith(".json")):
        dbutils.fs.cp(file.path, file_path + "/demo1")

# %%
for file in dbutils.fs.ls(file_path + "/movielens/"):
    if ( file.size < 200000 and file.size > 0):
        dbutils.fs.cp(file.path, file_path + "/demo1")

# %%
display(dbutils.fs.ls(file_path + "/demo1"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
for file in dbutils.fs.ls(file_path + "/demo1"):
    if (file.name.endswith(".json")):
        dbutils.fs.mv(file.path, file_path + "/demo2")

# %%
## %fs mv -r dbfs:/Volumes/workspace/default/data/movielens/ dbfs:/Volumes/workspace/default/data/demo1/

# %%
dbutils.fs.mv(
    "dbfs:/Volumes/workspace/default/data/movielens/", 
    file_path + "/demo2/movielens",
    recurse=True
)
# Out:
# True

# %%
display(dbutils.fs.ls(file_path + "/demo2"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(dbutils.fs.ls(file_path + "/demo1"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/default/data/demo1/links.csv</td><td>links.csv</td><td>183372</td><td>1787548840000</td></tr><tr><td>dbfs:/Volumes/workspace/default/data/demo1/tags.csv</td><td>tags.csv</td><td>41902</td><td>1787548841000</td></tr><tr><td>dbfs:/Volumes/workspace/default/data/demo1/test.csv</td><td>test.csv</td><td>4332</td><td>1787548842000</td></tr></tbody></table></div>

# %%
print(dbutils.fs.head("dbfs:/Volumes/workspace/default/data/demo1/test.csv"))
# Out:
# 1,31,2.5,1260759144
# 1,1029,3.0,1260759179
# 1,1061,3.0,1260759182
# 1,1129,2.0,1260759185
# 1,1172,4.0,1260759205
# 1,1263,2.0,1260759151
# 1,1287,2.0,1260759187
# 1,1293,2.0,1260759148
# 1,1339,3.5,1260759125
# 1,1343,2.0,1260759131
# 1,1371,2.5,1260759135
# 1,1405,1.0,1260759203
# 1,1953,4.0,1260759191
# 1,2105,4.0,1260759139
# 1,2150,3.0,1260759194
# 1,2193,2.0,1260759198
# 1,2294,2.0,1260759108
# 1,2455,2.5,1260759113
# 1,2968,1.0,1260759200
# 1,3671,3.0,1260759117
# 2,10,4.0,835355493
# 2,17,5.0,835355681
# 2,39,5.0,835355604
# 2,47,4.0,835355552
# 2,50,4.0,835355586
# 2,52,3.0,835356031
# 2,62,3.0,835355749
# 2,110,4.0,835355532
# 2,144,3.0,835356016
# 2,150,5.0,835355395
# 2,153,4.0,835355441
# 2,161,3.0,835355493
# 2,165,3.0,835355441
# 2,168,3.0,835355710
# 2,185,3.0,835355511
# 2,186,3.0,835355664
# 2,208,3.0,835355511
# 2,222,5.0,835355840
# 2,223,1.0,835355749
# 2,225,3.0,835355552
# 2,235,3.0,835355664
# 2,248,3.0,835355896
# 2,253,4.0,835355511
# 2,261,4.0,835355681
# ...

# %%
dbutils.fs.rm("dbfs:/Volumes/workspace/default/data/demo1/tags.csv")
# Out:
# True

# %%
dbutils.fs.rm(file_path + "/demo1", True)
# Out:
# True

# %%
dbutils.fs.rm(file_path + "/demo2", True)
# Out:
# True

# %%
display(dbutils.fs.ls(file_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
