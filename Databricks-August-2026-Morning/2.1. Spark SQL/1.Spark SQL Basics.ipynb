# %%
inputData = "/Volumes/workspace/default/data/users.json"

# %% [markdown]
# **Creating a DataFrame**

# %%
df1 = spark.read.format("json").load(inputData)

# %% [markdown]
# **Transform the DataFrame using Transformations API**

# %% [markdown]
# **Transform the DataFrame using SQL API**

# %% [markdown]
# **Use SQL cell**

# %% [markdown]
# **Writing the DataFrame to a target location**

# %% [markdown]
# **Save Modes**
#
# - Define what should happen when you are writing to an existing directory
#   - ErrorIfExists (default)
#   - Ignore
#   - Append   (appends additional files to the existing directory)
#   - Overwrite (overwrites old directory)
