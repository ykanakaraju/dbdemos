# %% [markdown]
# ### Working with different file formats
#
# [Documentation](https://spark.apache.org/docs/3.5.3/sql-data-sources-csv.html)

# %% [markdown]
# #### JSON file format

# %%
inputPath = "/FileStore/data/flight-data/json/2015_summary.json"
outputPath = "/FileStore/output/json"

# %% [markdown]
# **Apply schema on the DF**

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
#my_schema = "ORIGIN_COUNTRY_NAME STRING, DEST_COUNTRY_NAME STRING, count INT"

# %% [markdown]
# **Working with multi-line JSON file**

# %%
multi_line_json = "dbfs:/FileStore/data/users_multiline-1.json"

# %% [markdown]
# **Reading from nested JSON**

# %%
nested_json = "dbfs:/FileStore/data/users_nested-1.json"

# %% [markdown]
# #### Parquet file format

# %%
parquet_file = "dbfs:/FileStore/data/flight-data/parquet/2010-summary.parquet"

# %%
output_path_parquet = "/FileStore/output/parquet"

# %% [markdown]
# #### ORC file format

# %%
orc_file = "dbfs:/FileStore/data/flight-data/orc/2010-summary.orc"

# %%
output_path_orc = "/FileStore/output/orc"

# %% [markdown]
# #### CSV file format
# - Represents a delimited text file

# %%
csv_path = "dbfs:/FileStore/data/flight-data/csv"

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
my_schema = StructType(
    [
        StructField('ORIGIN_COUNTRY_NAME', StringType(), True), 
        StructField('DEST_COUNTRY_NAME', StringType(), True), 
        StructField('count', IntegerType(), True)
    ]
)

# %% [markdown]
# #### Text file format

# %%
text_path = "dbfs:/FileStore/data/wordcount.txt"
